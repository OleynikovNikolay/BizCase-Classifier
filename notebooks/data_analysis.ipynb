# %%
# analyzing the data
import pandas as pd

csv_path = '/Users/nik/personal_projects/BizCase-Classifier/data/processed/data_struct.csv'

df = pd.read_csv(csv_path, sep='|', quotechar = '"')

df
# Out:
#                 category_first_level  \
# 0                       Coarse genre
# 1     Included/forwarded information
# 2     Included/forwarded information
# 3     Included/forwarded information
# 4                       Coarse genre
# ...                              ...
# 5745                  Emotional tone
# 5746                  Emotional tone
# 5747                    Coarse genre
# 5748  Included/forwarded information
# 5749                  Emotional tone
#
#                                   category_second_level  frequency  \
# 0             Empty message (due to missing attachment)          1
# 1     Includes new text in addition to forwarded mat...          1
# 2                  Forwarded email(s) including replies          1
# 3                       Attachment(s) (assumed missing)          1
# 4             Empty message (due to missing attachment)          1
# ...                                                 ...        ...
# 5745                                         admiration          2
# 5746                                              pride          1
# 5747  Employment arrangements (job seeking, hiring, ...          2
# 5748                    Attachment(s) (assumed missing)          2
# 5749                                hope / anticipation          2
#
#                                               mail_text
# 0     Message-ID: <20902759.1075846162054.JavaMail.e...
# 1     Message-ID: <20902759.1075846162054.JavaMail.e...
# 2     Message-ID: <20902759.1075846162054.JavaMail.e...
# 3     Message-ID: <20902759.1075846162054.JavaMail.e...
# 4     Message-ID: <9865211.1075863435418.JavaMail.ev...
# ...                                                 ...
# 5745  Message-ID: <28790569.1075852654964.JavaMail.e...
# 5746  Message-ID: <28790569.1075852654964.JavaMail.e...
# 5747  Message-ID: <31083979.1075852655122.JavaMail.e...
# 5748  Message-ID: <31083979.1075852655122.JavaMail.e...
# 5749  Message-ID: <31083979.1075852655122.JavaMail.e...
#
# [5750 rows x 4 columns]
